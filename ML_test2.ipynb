# %%
""" Second take on machine learning features... 

CURRENTLY TESTING:
1. Counts on common intervals/steps? (step pattern of 0,3,7 for minor, vs. 0,4,7 for major)
2. Minor mode offers 9 notes (incl. ) vs. majors 7 notes

Add:
1. #1 is looking promising. Need to handle for case when no discernible difference. 
2. Need to scale step frequency to be relevent to num of total notes (%age rather than abs)
3. Should I put in all steps/interval data and let algorithm do the heavy lifting?
    (Rather than calculate count of patterns I'm expecting)
4. #2 is also looking promising. Pare out rarely using notes (<1% of all notes?) 
to better define most frequently used. 

------------------

Notes from Henry:
Ideally you want the machine to do all the work without putting computation in yourself.
Potentially try minimal computation first—at least to establish the baseline. 

- Stick with Logistic regression for first stab
- Naive Bayes may also work
- Random forest (Adaboost is a variation on this).... may not be right for this problem
- SVM tends to need more tweaking 

"""

###############################################

import music21
import pandas as pd
import numpy as np
from pandas.tools.plotting import scatter_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
training_data = []

# read test files and construct columns
filenames = open('test_files.txt').read().split('\n')

for filename in filenames:
    
    # Create empty score_instance to hold data of training features + outcome
    score_instance = {}

    # Convert MIDI file to score and iterate over notes in score 
    # Save relevant individual Note attributes into list (incl. Note obj, name, freq, major/minor at given measure)
    score = music21.converter.parse('MIDI test files/Cello solos/' + filename)
    note_attributes = []
    for note in music21.alpha.theoryAnalysis.theoryAnalyzer.getNotes(score, 0):
        if note == None:
            pass
        else:
#             measure = int(note.offset)
#             key = music21.alpha.theoryAnalysis.theoryAnalyzer.getKeyAtMeasure(score, measure)
            note_attributes.append([note, note.name, note.frequency])
    print "Note attributes for file {} completed".format(filename)
            
    # Calculate global attributes of score (incl: Avg interval, avg steps, is_major)
    # Note: At the moment, this doesn't take into account changes b/w major + minor w/in a score

    score_instance['note_count'] = {}
    for i in range(len(note_attributes)):
        note_name = note_attributes[i][1]
        score_instance['note_count'][note_name] = score_instance['note_count'].get(note_name, 0) + 1
    
    count_maj_interval = 0
    count_min_interval = 0
    
    for i in range(1, len(note_attributes)-1):
        interval_1 = music21.interval.Interval(noteStart=note_attributes[i-1][0], noteEnd=note_attributes[i][0])
        interval_2 = music21.interval.Interval(noteStart=note_attributes[i][0], noteEnd=note_attributes[i+1][0])

        step_1 = ((interval_1.cents)/100.00)
        step_2 = ((interval_2.cents)/100.00)
 
        if (step_1 == 3 and step_2 == 4) or (step_1 == -4 and step_2 == -3):
            count_min_interval += 1
        if (step_1 == 4 and step_2 == 5) or (step_1 == -5 and step_2 == -4):
            count_min_interval += 1
            
        if (step_1 == 4 and step_2 == 3) or (step_1 == -3 and step_2 == -4):
            count_maj_interval += 1
        if (step_1 == 3 and step_2 == 5) or (step_1 == -5 and step_2 == -3):
            count_maj_interval += 1
            
    mode_at_measure_0 = music21.alpha.theoryAnalysis.theoryAnalyzer.getKeyAtMeasure(score, 0).mode
    is_major = (mode_at_measure_0 == 'major')
    
    # Saves all global attributes into a dictionary and appends to global set of all training data
    # Used to create df and plt below
    score_instance['count_maj_interval'] = count_maj_interval
    score_instance['count_min_interval'] = count_min_interval
    score_instance['is_major'] = is_major    
    
    print "Global attributes include: {}".format(score_instance)
    training_data.append(score_instance)
# Out:
# Note attributes for file cs1-1pre.mid completed
# Global attributes include: {'note_count': {'A': 81, 'E-': 6, 'C': 68, 'B': 78, 'E': 63, 'D': 80, 'G': 95, 'F': 12, 'C#': 18, 'B-': 3, 'F#': 84, 'G#': 5}, 'is_major': True, 'count_maj_interval': 8, 'count_min_interval': 3}
# Note attributes for file cs1-2all.mid completed
# Global attributes include: {'note_count': {'A': 148, 'E-': 2, 'C': 100, 'B': 130, 'E': 96, 'D': 138, 'G': 152, 'F': 16, 'C#': 26, 'B-': 4, 'F#': 94, 'G#': 8}, 'is_major': True, 'count_maj_interval': 34, 'count_min_interval': 12}
# Note attributes for file cs1-3cou.mid completed
# Global attributes include: {'note_count': {'A': 132, 'E-': 8, 'C': 88, 'B': 120, 'E': 84, 'D': 116, 'G': 136, 'F': 18, 'C#': 22, 'F#': 88}, 'is_major': True, 'count_maj_interval': 12, 'count_min_interval': 2}
# Note attributes for file cs1-4sar.mid completed
# Global attributes include: {'note_count': {'A': 32, 'E-': 6, 'C': 24, 'B': 38, 'E': 36, 'D': 36, 'G': 38, 'F': 4, 'C#': 10, 'F#': 34, 'G#': 2}, 'is_major': True, 'count_maj_interval': 6, 'count_min_interval': 2}
# Note attributes for file cs1-5men.mid completed
# Global attributes include: {'note_count': {'A': 94, 'E-': 30, 'C': 68, 'B': 59, 'E': 49, 'D': 110, 'G': 89, 'F': 28, 'C#': 3, 'B-': 42, 'F#': 65, 'G#': 5}, 'is_major': True, 'count_maj_interval': 30, 'count_min_interval': 11}
# Note attributes for file cs1-6gig.mid completed
# Global attributes include: {'note_count': {'A': 64, 'E-': 8, 'C': 34, 'B': 50, 'E': 50, 'D': 60, 'G': 80, 'F': 12, 'C#': 8, 'B-': 10, 'F#': 44}, 'is_major': True, 'count_maj_interval': 22, 'count_min_interval': 12}
# Note attributes for file cs2-1pre.mid completed
# Global attributes include: {'note_count': {'A': 101, 'E-': 13, 'C': 46, 'B': 28, 'E': 75, 'D': 95, 'G': 83, 'F': 84, 'C#': 36, 'B-': 52, 'F#': 8, 'G#': 13}, 'is_major': False, 'count_maj_interval': 17, 'count_min_interval': 30}
# Note attributes for file cs2-2all.mid completed
# Global attributes include: {'note_count': {'A': 110, 'E-': 14, 'C': 50, 'B': 32, 'E': 78, 'D': 120, 'G': 72, 'F': 68, 'C#': 26, 'B-': 58, 'F#': 18, 'G#': 24}, 'is_major': False, 'count_maj_interval': 20, 'count_min_interval': 30}
# Note attributes for file cs2-3cou.mid completed
# Global attributes include: {'note_count': {'A': 114, 'E-': 12, 'C': 28, 'B': 26, 'E': 70, 'D': 88, 'G': 62, 'F': 86, 'C#': 38, 'B-': 42, 'G#': 14}, 'is_major': False, 'count_maj_interval': 12, 'count_min_interval': 12}
# Note attributes for file cs2-4sar.mid completed
# Global attributes include: {'note_count': {'A': 42, 'E-': 6, 'C': 18, 'B': 12, 'E': 48, 'D': 60, 'G': 40, 'F': 50, 'C#': 18, 'B-': 28, 'F#': 4, 'G#': 2}, 'is_major': False, 'count_maj_interval': 2, 'count_min_interval': 0}
# Note attributes for file cs2-5men.mid completed
# Global attributes include: {'note_count': {'A': 74, 'E-': 2, 'C': 27, 'B': 33, 'E': 56, 'D': 66, 'G': 75, 'F': 27, 'C#': 48, 'B-': 41, 'F#': 40}, 'is_major': False, 'count_maj_interval': 5, 'count_min_interval': 5}
# Note attributes for file cs2-6gig.mid completed
# Global attributes include: {'note_count': {'A': 100, 'E-': 18, 'C': 70, 'B': 34, 'E': 86, 'D': 118, 'G': 88, 'F': 84, 'C#': 18, 'B-': 58, 'F#': 8, 'G#': 8}, 'is_major': False, 'count_maj_interval': 6, 'count_min_interval': 8}
# Note attributes for file cs3-1pre.mid completed
# Global attributes include: {'note_count': {'A': 123, 'E-': 12, 'C': 138, 'B': 122, 'E': 112, 'D': 101, 'G': 154, 'F': 106, 'C#': 6, 'B-': 12, 'F#': 29, 'G#': 13}, 'is_major': True, 'count_maj_interval': 35, 'count_min_interval': 22}
# Note attributes for file cs3-2all.mid completed
# Global attributes include: {'note_count': {'A': 102, 'C': 160, 'B': 120, 'E': 136, 'D': 128, 'G': 110, 'F': 90, 'C#': 2, 'B-': 14, 'F#': 48, 'G#': 12}, 'is_major': True, 'count_maj_interval': 10, 'count_min_interval': 4}
# Note attributes for file cs3-3cou.mid completed
# Global attributes include: {'note_count': {'A': 142, 'E-': 16, 'C': 156, 'B': 122, 'E': 102, 'D': 148, 'G': 122, 'F': 86, 'C#': 2, 'B-': 20, 'F#': 46, 'G#': 22}, 'is_major': False, 'count_maj_interval': 66, 'count_min_interval': 26}
# Note attributes for file cs3-4sar.mid completed
# Global attributes include: {'note_count': {'A': 22, 'C': 32, 'B': 30, 'E': 20, 'D': 22, 'G': 30, 'F': 20, 'C#': 2, 'B-': 6, 'F#': 12}, 'is_major': True, 'count_maj_interval': 0, 'count_min_interval': 0}
# Note attributes for file cs3-5bou.mid completed
# Global attributes include: {'note_count': {'A': 77, 'E-': 44, 'C': 140, 'B': 109, 'E': 97, 'D': 128, 'G': 123, 'F': 76, 'B-': 28, 'F#': 24, 'G#': 26}, 'is_major': True, 'count_maj_interval': 39, 'count_min_interval': 10}
# Note attributes for file cs3-6gig.mid completed
# Global attributes include: {'note_count': {'A': 102, 'E-': 4, 'C': 106, 'B': 84, 'E': 64, 'D': 98, 'G': 96, 'F': 30, 'C#': 6, 'B-': 14, 'F#': 26, 'G#': 14}, 'is_major': True, 'count_maj_interval': 14, 'count_min_interval': 8}
# Note attributes for file cs4-1pre.mid completed
# Global attributes include: {'note_count': {'E-': 109, 'A': 47, 'C': 80, 'B': 19, 'E': 28, 'D': 71, 'G': 113, 'F': 60, 'C#': 25, 'B-': 114, 'F#': 50, 'G#': 73}, 'is_major': True, 'count_maj_interval': 9, 'count_min_interval': 14}
# Note attributes for file cs4-2all.mid completed
# Global attributes include: {'note_count': {'E-': 146, 'A': 44, 'C': 146, 'B': 12, 'E': 2, 'D': 144, 'G': 152, 'F': 144, 'C#': 14, 'B-': 136, 'F#': 8, 'G#': 98}, 'is_major': False, 'count_maj_interval': 6, 'count_min_interval': 2}
# Note attributes for file cs4-3cou.mid completed
# Global attributes include: {'note_count': {'E-': 154, 'A': 46, 'C': 112, 'B': 18, 'E': 6, 'D': 116, 'G': 124, 'F': 138, 'C#': 6, 'B-': 104, 'F#': 2, 'G#': 76}, 'is_major': False, 'count_maj_interval': 6, 'count_min_interval': 4}
# Note attributes for file cs4-4sar.mid completed
# Global attributes include: {'note_count': {'E-': 14, 'A': 6, 'C': 22, 'B': 4, 'E': 4, 'D': 16, 'G': 26, 'F': 24, 'C#': 6, 'B-': 18, 'G#': 18}, 'is_major': True, 'count_maj_interval': 2, 'count_min_interval': 2}
# Note attributes for file cs4-5bou.mid completed
# Global attributes include: {'note_count': {'E-': 203, 'A': 24, 'C': 153, 'B': 27, 'E': 3, 'D': 141, 'G': 196, 'F': 199, 'C#': 9, 'B-': 180, 'G#': 158}, 'is_major': True, 'count_maj_interval': 10, 'count_min_interval': 6}
# Note attributes for file cs4-6gig.mid completed
# Global attributes include: {'note_count': {'E-': 140, 'A': 58, 'C': 130, 'B': 18, 'E': 12, 'D': 128, 'G': 142, 'F': 98, 'C#': 6, 'B-': 130, 'F#': 34, 'G#': 70}, 'is_major': False, 'count_maj_interval': 30, 'count_min_interval': 10}
# Note attributes for file cs5-1pre.mid completed
# Global attributes include: {'note_count': {'A': 43, 'E-': 120, 'C': 131, 'B': 37, 'E': 25, 'D': 111, 'G': 128, 'F': 113, 'C#': 7, 'B-': 81, 'F#': 16, 'G#': 67}, 'is_major': False, 'count_maj_interval': 11, 'count_min_interval': 9}
# Note attributes for file cs5-2all.mid completed
# Global attributes include: {'note_count': {'E-': 40, 'A': 18, 'C': 38, 'B': 10, 'E': 4, 'D': 54, 'G': 60, 'F': 42, 'B-': 34, 'F#': 6, 'G#': 38}, 'is_major': False, 'count_maj_interval': 0, 'count_min_interval': 4}
# Note attributes for file cs5-3cou.mid completed
# Global attributes include: {'note_count': {'E-': 32, 'A': 14, 'C': 42, 'B': 10, 'D': 42, 'G': 38, 'F': 28, 'C#': 8, 'B-': 16, 'F#': 4, 'G#': 26}, 'is_major': False, 'count_maj_interval': 0, 'count_min_interval': 0}
# Note attributes for file cs5-4sar.mid completed
# Global attributes include: {'note_count': {'E-': 24, 'A': 4, 'C': 36, 'B': 18, 'E': 12, 'D': 18, 'G': 32, 'F': 26, 'C#': 6, 'B-': 16, 'F#': 6, 'G#': 18}, 'is_major': False, 'count_maj_interval': 4, 'count_min_interval': 0}
# Note attributes for file cs5-5gav.mid completed
# Global attributes include: {'note_count': {'E-': 148, 'A': 45, 'C': 146, 'B': 53, 'E': 30, 'D': 145, 'G': 187, 'F': 178, 'C#': 9, 'B-': 80, 'F#': 8, 'G#': 78}, 'is_major': False, 'count_maj_interval': 19, 'count_min_interval': 12}
# Note attributes for file cs5-6gig.mid completed
# Global attributes include: {'note_count': {'E-': 64, 'A': 14, 'C': 52, 'B': 16, 'E': 8, 'D': 62, 'G': 78, 'F': 54, 'C#': 2, 'B-': 40, 'F#': 8, 'G#': 38}, 'is_major': False, 'count_maj_interval': 4, 'count_min_interval': 6}
# Note attributes for file cs6-1pre.mid completed
# Global attributes include: {'note_count': {'A': 197, 'E-': 15, 'C': 21, 'B': 155, 'E': 170, 'D': 194, 'G': 133, 'F': 12, 'C#': 139, 'B-': 14, 'F#': 161, 'G#': 28}, 'is_major': True, 'count_maj_interval': 82, 'count_min_interval': 41}
# Note attributes for file cs6-2all.mid completed
# Global attributes include: {'note_count': {'A': 132, 'E-': 10, 'C': 30, 'B': 98, 'E': 98, 'D': 110, 'G': 80, 'F': 8, 'C#': 78, 'B-': 2, 'F#': 132, 'G#': 50}, 'is_major': False, 'count_maj_interval': 24, 'count_min_interval': 8}
# Note attributes for file cs6-3cou.mid completed
# Global attributes include: {'note_count': {'A': 182, 'E-': 2, 'C': 18, 'B': 146, 'E': 200, 'D': 208, 'G': 116, 'C#': 162, 'B-': 8, 'F#': 188, 'G#': 48}, 'is_major': True, 'count_maj_interval': 4, 'count_min_interval': 2}
# Note attributes for file cs6-4sar.mid completed
# Global attributes include: {'note_count': {'A': 22, 'E-': 4, 'C': 6, 'B': 8, 'E': 46, 'D': 24, 'G': 16, 'F': 8, 'C#': 4, 'F#': 24}, 'is_major': True, 'count_maj_interval': 0, 'count_min_interval': 0}
# Note attributes for file cs6-5gav.mid completed
# Global attributes include: {'note_count': {'A': 113, 'E-': 6, 'C': 2, 'B': 82, 'E': 127, 'D': 135, 'G': 64, 'C#': 84, 'B-': 6, 'F#': 136}, 'is_major': True, 'count_maj_interval': 5, 'count_min_interval': 0}
# Note attributes for file cs6-6gig.mid completed
# Global attributes include: {'note_count': {'A': 175, 'C': 8, 'B': 142, 'E': 174, 'D': 173, 'G': 95, 'C#': 118, 'B-': 16, 'F#': 167, 'G#': 49}, 'is_major': True, 'count_maj_interval': 29, 'count_min_interval': 3}

# %%
for instance in training_data:
    proportion_maj = instance['count_maj_interval']/(instance['count_maj_interval'] + instance['count_min_interval'])
    proportion_min = instance['count_min_interval']/(instance['count_maj_interval'] + instance['count_min_interval'])
